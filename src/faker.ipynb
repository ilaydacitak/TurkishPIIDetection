# %%
from faker import Faker
from faker.providers import internet
from faker.providers import credit_card
from faker.providers import address

# %%
fake = Faker('tr_TR')
fake.add_provider(internet)
fake.add_provider(credit_card)
fake.add_provider(address)

# %%
for _ in range(10):
    print(fake.address())
# Out:
# 315 Yüksel Fords Suite 892
# Görklüstad, GA 17347
# 4912 Yorulmaz Parkways
# Port Oranlıfort, OR 51788
# 948 Duran Stream
# Yükselville, SC 51943
# 91763 Seven Motorway
# New Koruganchester, AZ 22667
# 1070 Dumanlı Glens
# East Kaygusuzshire, AK 94489
# 247 Duran Loaf
# Lake Muhammet, MN 74942
# 521 Mutluhan Well Suite 972
# Akdenizland, GU 31531
# 48049 Söyler Corners Suite 466
# Gönenberg, MH 66503
# 83895 Nesip Ramp
# Çorlumouth, GA 60888
# 12139 Gilman Port
# New Cabir, TX 21213
